# %% [markdown]
# # 频率派与贝叶斯派
#
# 2019-01-23
# `ML`

# %% [markdown]
# ## 假设
#
# 假设 $\theta $ 表示 parameter， $X$ 表示 data：
#
# $$
# X={(X_1, X_2, ..., X_N)^T}_{N\times p}=\begin{pmatrix}
# x_{11} & x_{12} & ... & x_{1p} \\
# x_{21} & x_{22} & ... & x_{2p} \\
#  \vdots &  &  & \\
#  x_{N1} & x_{N2} & ... & x_{Np}
# \end{pmatrix}_{N\times p}
# $$

# %% [markdown]
# ## 频率派
#
# 频率派认为

# %% [markdown]
# ![](img/logo.png)
